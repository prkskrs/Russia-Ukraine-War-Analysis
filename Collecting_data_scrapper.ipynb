# %%
import pandas as pd
import numpy as np
#!pip install selenium
#!pip install BeautifulSoup4
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# # feb27

# %%
url_f27 =[ "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-27/2022-02-27_2.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-27/2022-02-27_3.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-27/2022-02-27_4.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-27/2022-02-27_5.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-27/2022-02-27_6.csv"]

feb_27 = pd.DataFrame()
for i in url_f27:
    fetch = pd.read_csv(i,header = None,delimiter = "\n")
    feb_27 = pd.concat([feb_27,fetch], ignore_index=True, sort=False)
feb_27.size
#feb_f27.head()
# Out:
# 211952

# %%
#feb_27.to_csv("feb_27_combined_tid.csv") #save as csv

# %% [markdown]
# # feb 28

# %%
url_f28 = [ "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_1.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_2.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_3.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_4.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_5.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_6.csv",
            "https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/2022-02-28/2022-02-28_7.csv"]
feb_28 = pd.DataFrame()
for i in url_f28:
    fetch = pd.read_csv(i,header = None,delimiter = "\n")
    feb_28 = pd.concat([feb_28,fetch], ignore_index=True, sort=False)

feb_28.size
#feb_28.head()
# Out:
# 296736

# %%
#338037 --> size
#feb_28.to_csv("feb_28_combined_tid.csv")

# %%
def scrapper(date):
    url = ("https://github.com/ehsanulhaq1/russo_ukraine_dataset/tree/main/"+date)
    page = urlopen(url)
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, "html.parser")

    
    raw_url ="https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/"
    li = []
    for i in range(1,20):
        ii ="_"+f'{i}'+".csv"
        p = soup.find("a",string=date+ii)
        if(p):
           li.append(raw_url+date+"/"+date+ii)


    url = li
    df = pd.DataFrame()
    for i in url:
        fetch = pd.read_csv(i,header = None,delimiter = "\n")
        df = pd.concat([df,fetch], ignore_index=True, sort=False)

    return df

# %%
idate = "2022-03-"
#test = pd.DataFrame()
for i in range (1,32):
    if i<10:
        ii ="0"+str(i)
    else:
        ii = str(i)
    date = idate+ii
    #test = pd.concat([scrapper(date),test] ,  ignore_index=True, sort=False)
    

print(test.shape)
n = len(pd.unique(test[0]))
print(n)
test.head()
#test.to_csv("combined_tid_FINAL", sep='\n',index = False)
# Out:
# (6858088, 1)
# 6854101

# %%
def scrappercount(date):
    url = ("https://github.com/ehsanulhaq1/russo_ukraine_dataset/tree/main/"+date)
    page = urlopen(url)
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, "html.parser")

    
    raw_url ="https://raw.githubusercontent.com/ehsanulhaq1/russo_ukraine_dataset/main/"
    li = []
    for i in range(2,20):
        ii ="_"+f'{i}'+".csv"
        p = soup.find("a",string=date+ii)
        if(p):
           li.append(raw_url+date+"/"+date+ii)


    url = li
    df = pd.DataFrame()
    for i in url:
        fetch = pd.read_csv(i,header = None,delimiter = "\n")
        print(date +" "+str(len((fetch))))

    return df

# %%
idate = "2022-03-"
test = pd.DataFrame()
for i in range (1,32):
    if i<10:
        ii ="0"+str(i)
    else:
        ii = str(i)
    date = idate+ii
    scrappercount(date)
# Out:
# 2022-03-01 33875
